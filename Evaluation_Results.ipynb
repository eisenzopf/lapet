# %%
import pandas as pd

# %%
df = pd.read_csv('eval_results.csv')

# %%
df
# Out:
#     Unnamed: 0                                id  \
# 0            0  39175fc09991400aafac090ce1a1a79a
# 1            1  39175fc09991400aafac090ce1a1a79a
# 2            2  39175fc09991400aafac090ce1a1a79a
# 3            3  39175fc09991400aafac090ce1a1a79a
# 4            4  39175fc09991400aafac090ce1a1a79a
# ..         ...                               ...
# 85          85  919de8eab7e54cb3b00f88f889c760e5
# 86          86  919de8eab7e54cb3b00f88f889c760e5
# 87          87  919de8eab7e54cb3b00f88f889c760e5
# 88          88  919de8eab7e54cb3b00f88f889c760e5
# 89          89  919de8eab7e54cb3b00f88f889c760e5
#
#                                           instruction  \
# 0   ### Conversation ###\nagent: Hello, thank you ...
# 1   ### Conversation ###\nagent: Hello, thank you ...
# 2   ### Conversation ###\nagent: Hello, thank you ...
# 3   ### Conversation ###\nagent: Hello, thank you ...
# 4   ### Conversation ###\nagent: Hello, thank you ...
# ..                                                ...
# 85  ### Conversation ###\nagent: Thank you for cal...
# 86  ### Conversation ###\nagent: Thank you for cal...
# 87  ### Conversation ###\nagent: Thank you for cal...
# 88  ### Conversation ###\nagent: Thank you for cal...
# 89  ### Conversation ###\nagent: Thank you for cal...
#
#                                  model1                               model2  \
# 0         meta-llama/Llama-2-7b-chat-hf  meta-llama/Meta-Llama-3-8B-Instruct
# 1         meta-llama/Llama-2-7b-chat-hf  meta-llama/Meta-Llama-3-8B-Instruct
# 2         meta-llama/Llama-2-7b-chat-hf  meta-llama/Meta-Llama-3-8B-Instruct
# 3         meta-llama/Llama-2-7b-chat-hf  meta-llama/Meta-Llama-3-8B-Instruct
# 4         meta-llama/Llama-2-7b-chat-hf  meta-llama/Meta-Llama-3-8B-Instruct
# ..                                  ...                                  ...
# 85  meta-llama/Meta-Llama-3-8B-Instruct     microsoft/Phi-3-mini-4k-instruct
# 86  meta-llama/Meta-Llama-3-8B-Instruct     microsoft/Phi-3-mini-4k-instruct
# 87  meta-llama/Meta-Llama-3-8B-Instruct     microsoft/Phi-3-mini-4k-instruct
# 88  meta-llama/Meta-Llama-3-8B-Instruct     microsoft/Phi-3-mini-4k-instruct
# 89  meta-llama/Meta-Llama-3-8B-Instruct     microsoft/Phi-3-mini-4k-instruct
#
#              test.name                                        comp1.value  \
# 0      intent-sentence  The customer wants to inquire about the measur...
# 1         intent-label                                       PROTECT_DATA
# 2   customer-sentiment                                            Neutral
# 3        agent-empathy                                               High
# 4              outcome                                                Yes
# ..                 ...                                                ...
# 85        intent-label                            Resolve Messaging Issue
# 86  customer-sentiment                                           Negative
# 87       agent-empathy                                            Average
# 88             outcome                                                 no
# 89             summary  Esteban contacted Union Mobile to report issue...
#
#                                           comp2.value  \
# 0   The customer wants to know what measures Union...
# 1                                Seek Data Protection
# 2                                            Positive
# 3                                                High
# 4                                                 Yes
# ..                                                ...
# 85                               Secure Messaging Fix
# 86                                           Negative
# 87                                               High
# 88                                                 No
# 89  Esteban, a Union Mobile customer, contacted th...
#
#                              preference  \
# 0   meta-llama/Meta-Llama-3-8B-Instruct
# 1   meta-llama/Meta-Llama-3-8B-Instruct
# 2   meta-llama/Meta-Llama-3-8B-Instruct
# 3                                   tie
# 4                                   tie
# ..                                  ...
# 85     microsoft/Phi-3-mini-4k-instruct
# 86                                  tie
# 87     microsoft/Phi-3-mini-4k-instruct
# 88     microsoft/Phi-3-mini-4k-instruct
# 89  meta-llama/Meta-Llama-3-8B-Instruct
#
#                                           explanation
# 0   Participant 2's response more closely aligns w...
# 1   The instruction requires a two-word label with...
# 2   I prefer participant 1's response because the ...
# 3   Both participants provided the same output, "H...
# 4   Both participants' responses are identical and...
# ..                                                ...
# 85  The response from participant 2, "Secure Messa...
# 86  Both participants provided the same sentiment ...
# 87  Participant 1's response ("High") aligns more ...
# 88  The response from participant 2 correctly adhe...
# 89  Both participants provided accurate summaries,...
#
# [90 rows x 10 columns]

# %%
df['preference'].value_counts()
# Out:
# preference
# microsoft/Phi-3-mini-4k-instruct       37
# meta-llama/Meta-Llama-3-8B-Instruct    28
# tie                                    14
# meta-llama/Llama-2-7b-chat-hf          11
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
df['preference'].value_counts().plot(kind='bar', color='blue')
plt.title('Preference Counts')
plt.xlabel('Preference')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
